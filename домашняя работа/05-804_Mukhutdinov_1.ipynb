# %%
from matplotlib.image import imread, imsave

import matplotlib.pyplot as plt
#160 360   480 680
# 200  220 

def calculete(begin_x,begin_y):
    sum_r=0
    sum_g=0
    sum_b=0
    for i in range (begin_x,begin_x+20):
        for j in range (begin_y,begin_y+22):
            global orig_img 
            
            sum_r=sum_r+orig_img[i,j,0]
            sum_g+=orig_img[i,j,1]
            sum_b+=orig_img[i,j,2]
            
    print (sum_r)
    return [sum_r/440,sum_g/440,sum_b/440]
    
def qwe ():
    for i in range (0,10):
        for j in range (0,10):
            global orig_img
            a=calculete(160+i*20,480+j*22)
            
            orig_img[160+i*20:160+(i+1)*20,480+j*22:480+(j+1)*22,0]=a[0]
            orig_img[160+i*20:160+(i+1)*20,480+j*22:480+(j+1)*22,1]=a[1]
            orig_img[160+i*20:160+(i+1)*20,480+j*22:480+(j+1)*22,2]=a[2]
orig_img = imread('data/01.jpg')
plt.imshow(orig_img)
plt.show()
print(orig_img.shape)
print(orig_img)
print(orig_img[160,480])

qwe()

plt.imshow(orig_img.copy())
plt.show()

imsave('data/01_new.jpg', test)
# Out:
# (768, 1024, 3)
# [[[ 86 108 157]
#   [ 86 108 157]
#   [ 86 108 157]
#   ...
#   [ 86 108 157]
#   [ 86 108 157]
#   [ 86 108 157]]
#
#  [[ 86 108 157]
#   [ 86 108 157]
#   [ 86 108 157]
#   ...
#   [ 86 108 157]
#   [ 86 108 157]
#   [ 86 108 157]]
#
#  [[ 86 108 157]
#   [ 86 108 157]
#   [ 86 108 157]
#   ...
#   [ 86 108 157]
#   [ 86 108 157]
#   [ 86 108 157]]
#
#  ...
#
#  [[156 182 233]
#   [156 182 233]
#   [156 182 233]
#   ...
#   [158 184 235]
#   [160 182 240]
#   [158 182 230]]
#
#  [[156 182 233]
#   [156 182 233]
#   [156 182 233]
#   ...
#   [158 186 233]
#   [156 181 238]
#   [160 180 233]]
#
#  [[156 182 233]
#   [156 182 233]
#   [156 182 233]
#   ...
#   [151 185 223]
#   [155 186 232]
#   [159 181 238]]]
# [ 96 120 168]
# 50567
# 65079
# 53942
# 58114
# 51422
# 38006
# 31742
# 23526
# 21452
# 25379
# 44689
# 78871
# 62799
# 74509
# 46249
# 61756
# 35976
# 29120
# 30725
# 31349
# 56877
# 103030
# 52810
# 64880
# 79007
# 49511
# 36630
# 32197
# 29251
# 25345
# ...
